# %%
import tracemalloc
import background_generation as backgen
import numpy as np
import pickle
from pathlib import Path
from PIL import Image
import sys
from matplotlib import pyplot as plt

import background_generation as backgen
#windows
sys.path.insert(0, r"C:\Users\adria\Documents\Mestrado\texture_codes\modules")
root_dir = Path(r"C:\Users\adria\Documents\Mestrado\texture_codes\modules")

#linux
#sys.path.insert(0, "/home/adriano/projeto_mestrado/modules/")
#root_dir = f"/home/adriano/projeto_mestrado/modules"

if __name__ == '__main__':

    #Aumentar o limiar para testar se fica compatível no máximo valor
    #Gerar as curvas de bezier dentro do algoritmo - tamanho setado pelo cliente - distancia entre o ponto 1 e ponto 2, numero de pontos, max_vd, 
    parameters ={
        'dir_maps_pickle': f'{root_dir}/Vessel_models_pickle/retina/10_maps',  # directory of pickles        
        'dir_mask': f'{root_dir}/Images/retina/mask',  # directory of pickles
        'num_maps': 10,  # number of maps to be inserted
        'num_images': 97, # number of images desired
        'dir_backs': f'{root_dir}/Images/retina/backgrounds',  # background's directory
        #'dir_images': f'{root_dir}/Images/retina/images_training',  # original images directory
        #'dir_labels': f'{root_dir}/Images/retina/labels_training',  # label directory       
        'generate_back': False,  # whether to generate background images       
        'out_dir_images': f'{root_dir}/Training_validation_retina/Artificial_images/Generated_from_10_maps/pack4/images',  # output directory of images
        'out_dir_labels': f'{root_dir}/Training_validation_retina/Artificial_images/Generated_from_10_maps/pack4/labels',  # output directory of labels
        'min_number_vessels': 15,  # minimum number of vessels
        'max_number_vessels': 30,  # maximum number of vessels
        'threshold': 30,  # parameter that defines the threshold between the differences of the map background and the overall background
        
        # Bezier Curves parameters
        'max_distance': 500,  # maximum distance where control points will be randomly drawn. Example: 1 generates straight lines.
        'control_points': 6,  # number of control points between pe and ps. The higher this number, the more curves are generated.
        'precision': 100,  # number of points generated
        'number_cols': 900,  # maximum number of columns for the Bezier curve
        'number_rows': 900,  # maximum number of rows for the Bezier curve
        'number_points': 25,  # determine the number of random points to be generated
        'min_len_trace': 400,  # minimum distance between the initial and final points
        'max_len_trace': 900,  # maximum distance between the initial and final points
        'padding': 50,  # padding used to ensure that the trace does not exceed the size of the background
    }
    backgen.generate_backgrounds_with_vessels_retina(parameters)
# Out:
# normalized_original_map NONE
# 1
# normalized_original_map NONE
# 2
# normalized_original_map NONE
# 3
# normalized_original_map NONE
# 4
# normalized_original_map NONE
# 5
# normalized_original_map NONE
# 6
# normalized_original_map NONE
# 7
# normalized_original_map NONE
# 8
# normalized_original_map NONE
# 9
# normalized_original_map NONE
# 10
# normalized_original_map NONE
# 11
# normalized_original_map NONE
# 12
# normalized_original_map NONE
# 13
# normalized_original_map NONE
# 14
# normalized_original_map NONE
# 15
# normalized_original_map NONE
# 16
# normalized_original_map NONE
# 17
# normalized_original_map NONE
# 18
# normalized_original_map NONE
# 19
# normalized_original_map NONE
# 20
# normalized_original_map NONE
# 21
# normalized_original_map NONE
# 22
# normalized_original_map NONE
# 23
# normalized_original_map NONE
# 24
# normalized_original_map NONE
# 25
# normalized_original_map NONE
# 26
# normalized_original_map NONE
# 27
# normalized_original_map NONE
# 28
# normalized_original_map NONE
# 29
# normalized_original_map NONE
# 30
# normalized_original_map NONE
# 31
# normalized_original_map NONE
# 32
# normalized_original_map NONE
# 33
# normalized_original_map NONE
# 34
# normalized_original_map NONE
# 35
# normalized_original_map NONE
# 36
# normalized_original_map NONE
# 37
# normalized_original_map NONE
# 38
# normalized_original_map NONE
# 39
# normalized_original_map NONE
# 40
# normalized_original_map NONE
# 41
# normalized_original_map NONE
# 42
# normalized_original_map NONE
# 43
# normalized_original_map NONE
# 44
# normalized_original_map NONE
# 45
# normalized_original_map NONE
# 46
# normalized_original_map NONE
# 47
# normalized_original_map NONE
# 48
# normalized_original_map NONE
# 49
# normalized_original_map NONE
# 50
# normalized_original_map NONE
# 51
# normalized_original_map NONE
# 52
# normalized_original_map NONE
# 53
# normalized_original_map NONE
# 54
# normalized_original_map NONE
# 55
# normalized_original_map NONE
# 56
# normalized_original_map NONE
# 57
# normalized_original_map NONE
# 58
# normalized_original_map NONE
# 59
# normalized_original_map NONE
# 60
# normalized_original_map NONE
# 61
# normalized_original_map NONE
# 62
# normalized_original_map NONE
# 63
# normalized_original_map NONE
# 64
# normalized_original_map NONE
# 65
# normalized_original_map NONE
# 66
# normalized_original_map NONE
# 67
# normalized_original_map NONE
# 68
# normalized_original_map NONE
# 69
# normalized_original_map NONE
# 70
# normalized_original_map NONE
# 71
# normalized_original_map NONE
# 72
# normalized_original_map NONE
# 73
# normalized_original_map NONE
# 74
# normalized_original_map NONE
# 75
# normalized_original_map NONE
# 76
# normalized_original_map NONE
# 77
# normalized_original_map NONE
# 78
# normalized_original_map NONE
# 79
# normalized_original_map NONE
# 80
# normalized_original_map NONE
# 81
# normalized_original_map NONE
# 82
# normalized_original_map NONE
# 83
# normalized_original_map NONE
# 84
# normalized_original_map NONE
# 85
# normalized_original_map NONE
# 86
# normalized_original_map NONE
# 87
# normalized_original_map NONE
# 88
# normalized_original_map NONE
# 89
# normalized_original_map NONE
# 90
# normalized_original_map NONE
# 91
# normalized_original_map NONE
# 92
# normalized_original_map NONE
# 93
# normalized_original_map NONE
# 94
# normalized_original_map NONE
# 95
# normalized_original_map NONE
# 96
# normalized_original_map NONE
# 97
# normalized_original_map NONE
# 98
# normalized_original_map NONE
# 99
# normalized_original_map NONE
# 100
# normalized_original_map NONE
# 101
# normalized_original_map NONE
# 102
# normalized_original_map NONE
# 103
# normalized_original_map NONE
# 104
# normalized_original_map NONE
# 105
# normalized_original_map NONE
# 106
# normalized_original_map NONE
# 107
# normalized_original_map NONE
# 108
# normalized_original_map NONE
# 109
# normalized_original_map NONE
# 110
# normalized_original_map NONE
# 111
# normalized_original_map NONE
# 112
# normalized_original_map NONE
# 113
# normalized_original_map NONE
# 114
# normalized_original_map NONE
# 115
# normalized_original_map NONE
# 116
# normalized_original_map NONE
# 117
# normalized_original_map NONE
# 118
# normalized_original_map NONE
# 119
# normalized_original_map NONE
# 120
# normalized_original_map NONE
# 121
# normalized_original_map NONE
# 122
# normalized_original_map NONE
# 123
# normalized_original_map NONE
# 124
# normalized_original_map NONE
# 125
# normalized_original_map NONE
# 126
# normalized_original_map NONE
# 127
# normalized_original_map NONE
# 128
# normalized_original_map NONE
# 129
# normalized_original_map NONE
# 130
# normalized_original_map NONE
# 131
# normalized_original_map NONE
# 132
# normalized_original_map NONE
# 133
# normalized_original_map NONE
# 134
# normalized_original_map NONE
# 135
# normalized_original_map NONE
# 136
# normalized_original_map NONE
# 137
# normalized_original_map NONE
# 138
# normalized_original_map NONE
# 139
# normalized_original_map NONE
# 140
# normalized_original_map NONE
# 141
# normalized_original_map NONE
# 142
# normalized_original_map NONE
# 143
# normalized_original_map NONE
# 144
# normalized_original_map NONE
# 145
# normalized_original_map NONE
# 146
# normalized_original_map NONE
# 147
# normalized_original_map NONE
# 148
# normalized_original_map NONE
# 149
# normalized_original_map NONE
# 150
# normalized_original_map NONE
# 151
# normalized_original_map NONE
# 152
# normalized_original_map NONE
# 153
# normalized_original_map NONE
# 154
# normalized_original_map NONE
# 155
# normalized_original_map NONE
# 156
# normalized_original_map NONE
# 157
# normalized_original_map NONE
# 158
# normalized_original_map NONE
# 159
# normalized_original_map NONE
# 160
# normalized_original_map NONE
# 161
# normalized_original_map NONE
# 162
# normalized_original_map NONE
# 163
# normalized_original_map NONE
# 164
# normalized_original_map NONE
# 165
# normalized_original_map NONE
# 166
# normalized_original_map NONE
# 167
# normalized_original_map NONE
# 168
# normalized_original_map NONE
# 169
# normalized_original_map NONE
# 170
# normalized_original_map NONE
# 171
# normalized_original_map NONE
# 172
# normalized_original_map NONE
# 173
# normalized_original_map NONE
# 174
# normalized_original_map NONE
# 175
# normalized_original_map NONE
# 176
# normalized_original_map NONE
# 177
# normalized_original_map NONE
# 178
# normalized_original_map NONE
# 179
# normalized_original_map NONE
# 180
# normalized_original_map NONE
# 181
# normalized_original_map NONE
# 182
# normalized_original_map NONE
# 183
# normalized_original_map NONE
# 184
# normalized_original_map NONE
# 185
# normalized_original_map NONE
# 186
# normalized_original_map NONE
# 187
# normalized_original_map NONE
# 188
# normalized_original_map NONE
# 189
# normalized_original_map NONE
# 190
# normalized_original_map NONE
# 191
# normalized_original_map NONE
# 192
# normalized_original_map NONE
# 193
# normalized_original_map NONE
# 194
# normalized_original_map NONE
# 195
# normalized_original_map NONE
# 196
# normalized_original_map NONE
# 197
# normalized_original_map NONE
# 198
# normalized_original_map NONE
# 199
# normalized_original_map NONE
# 200
# normalized_original_map NONE
# 201
# normalized_original_map NONE
# 202
# normalized_original_map NONE
# 203
# normalized_original_map NONE
# 204
# normalized_original_map NONE
# 205
# normalized_original_map NONE
# 206
# normalized_original_map NONE
# 207
# normalized_original_map NONE
# 208
# normalized_original_map NONE
# 209
# normalized_original_map NONE
# 210
# normalized_original_map NONE
# 211
# normalized_original_map NONE
# 212
# normalized_original_map NONE
# 213
# normalized_original_map NONE
# 214
# normalized_original_map NONE
# 215
# normalized_original_map NONE
# 216
# normalized_original_map NONE
# 217
# normalized_original_map NONE
# 218
# normalized_original_map NONE
# 219
# normalized_original_map NONE
# 220
# normalized_original_map NONE
# 221
# normalized_original_map NONE
# 222
# normalized_original_map NONE
# 223
# normalized_original_map NONE
# 224
# normalized_original_map NONE
# 225
# normalized_original_map NONE
# 226
# normalized_original_map NONE
# 227
# normalized_original_map NONE
# 228
# normalized_original_map NONE
# 229
# normalized_original_map NONE
# 230
# normalized_original_map NONE
# 231
# normalized_original_map NONE
# 232
# normalized_original_map NONE
# 233
# normalized_original_map NONE
# 234
# normalized_original_map NONE
# 235
# normalized_original_map NONE
# 236
# normalized_original_map NONE
# 237
# normalized_original_map NONE
# 238
# normalized_original_map NONE
# 239
# normalized_original_map NONE
# 240
# normalized_original_map NONE
# 241
# normalized_original_map NONE
# 242
# normalized_original_map NONE
# 243
# normalized_original_map NONE
# 244
# normalized_original_map NONE
# 245
# normalized_original_map NONE
# 246
# normalized_original_map NONE
# 247
# normalized_original_map NONE
# 248
# normalized_original_map NONE
# 249
# normalized_original_map NONE
# 250
# normalized_original_map NONE
# 251
# normalized_original_map NONE
# 252
# normalized_original_map NONE
# 253
# normalized_original_map NONE
# 254
# normalized_original_map NONE
# 255
# normalized_original_map NONE
# 256
# normalized_original_map NONE
# 257
# normalized_original_map NONE
# 258
# normalized_original_map NONE
# 259
# normalized_original_map NONE
# 260
# normalized_original_map NONE
# 261
# normalized_original_map NONE
# 262
# normalized_original_map NONE
# 263
# normalized_original_map NONE
# 264
# normalized_original_map NONE
# 265
# normalized_original_map NONE
# 266
# normalized_original_map NONE
# 267
# normalized_original_map NONE
# 268
# normalized_original_map NONE
# 269
# normalized_original_map NONE
# 270
# normalized_original_map NONE
# 271
# normalized_original_map NONE
# 272
# normalized_original_map NONE
# 273
# normalized_original_map NONE
# 274
# normalized_original_map NONE
# 275
# normalized_original_map NONE
# 276
# normalized_original_map NONE
# 277
# normalized_original_map NONE
# 278
# normalized_original_map NONE
# 279
# normalized_original_map NONE
# 280
# normalized_original_map NONE
# 281
# normalized_original_map NONE
# 282
# normalized_original_map NONE
# 283
# normalized_original_map NONE
# 284
# normalized_original_map NONE
# 285
# normalized_original_map NONE
# 286
# normalized_original_map NONE
# 287
# normalized_original_map NONE
# 288
# normalized_original_map NONE
# 289
# normalized_original_map NONE
# 290
# normalized_original_map NONE
# 291
# normalized_original_map NONE
# 292
# normalized_original_map NONE
# 293
# normalized_original_map NONE
# 294
# normalized_original_map NONE
# 295
# normalized_original_map NONE
# 296
# normalized_original_map NONE
# 297
# normalized_original_map NONE
# 298
# normalized_original_map NONE
# 299
# normalized_original_map NONE
# 300
# normalized_original_map NONE
# 301
# normalized_original_map NONE
# 302
# normalized_original_map NONE
# 303
# normalized_original_map NONE
# 304
# normalized_original_map NONE
# 305
# normalized_original_map NONE
# 306
# normalized_original_map NONE
# 307
# normalized_original_map NONE
# 308
# normalized_original_map NONE
# 309
# normalized_original_map NONE
# 310
# normalized_original_map NONE
# 311
# normalized_original_map NONE
# 312
# normalized_original_map NONE
# 313
# normalized_original_map NONE
# 314
# normalized_original_map NONE
# 315
# normalized_original_map NONE
# 316
# normalized_original_map NONE
# 317
# normalized_original_map NONE
# 318
# normalized_original_map NONE
# 319
# normalized_original_map NONE
# 320
# normalized_original_map NONE
# 321
# normalized_original_map NONE
# 322
# normalized_original_map NONE
# 323
# normalized_original_map NONE
# 324
# normalized_original_map NONE
# 325
# normalized_original_map NONE
# 326
# normalized_original_map NONE
# 327
# normalized_original_map NONE
# 328
# normalized_original_map NONE
# 329
# normalized_original_map NONE
# 330
# normalized_original_map NONE
# 331
# normalized_original_map NONE
# 332
# normalized_original_map NONE
# 333
# normalized_original_map NONE
# 334
# normalized_original_map NONE
# 335
# normalized_original_map NONE
# 336
# normalized_original_map NONE
# 337
# normalized_original_map NONE
# 338
# normalized_original_map NONE
# 339
# normalized_original_map NONE
# 340
# normalized_original_map NONE
# 341
# normalized_original_map NONE
# 342
# normalized_original_map NONE
# 343
# normalized_original_map NONE
# 344
# normalized_original_map NONE
# 345
# normalized_original_map NONE
# 346
# normalized_original_map NONE
# 347
# normalized_original_map NONE
# 348
# normalized_original_map NONE
# 349
# normalized_original_map NONE
# 350
# normalized_original_map NONE
# 351
# normalized_original_map NONE
# 352
# normalized_original_map NONE
# 353
# normalized_original_map NONE
# 354
# normalized_original_map NONE
# 355
# normalized_original_map NONE
# 356
# normalized_original_map NONE
# 357
# normalized_original_map NONE
# 358
# normalized_original_map NONE
# 359
# normalized_original_map NONE
# 360
# normalized_original_map NONE
# 361
# normalized_original_map NONE
# 362
# normalized_original_map NONE
# 363
# normalized_original_map NONE
# 364
# normalized_original_map NONE
# 365
# normalized_original_map NONE
# 366
# normalized_original_map NONE
# 367
# normalized_original_map NONE
# 368
# normalized_original_map NONE
# 369
# normalized_original_map NONE
# 370
# normalized_original_map NONE
# 371
# normalized_original_map NONE
# 372
# normalized_original_map NONE
# 373
# normalized_original_map NONE
# 374
# normalized_original_map NONE
# 375
# normalized_original_map NONE
# 376
# normalized_original_map NONE
# 377
# normalized_original_map NONE
# 378
# normalized_original_map NONE
# 379
# normalized_original_map NONE
# 380
# normalized_original_map NONE
# 381
# normalized_original_map NONE
# 382
# normalized_original_map NONE
# 383
# normalized_original_map NONE
# 384
# normalized_original_map NONE
# 385
# normalized_original_map NONE
# 386
# normalized_original_map NONE
# 387
# normalized_original_map NONE
# 388
# normalized_original_map NONE
# 389
# normalized_original_map NONE
# 390
# normalized_original_map NONE
# 391
# normalized_original_map NONE
# 392
# normalized_original_map NONE
# 393
# normalized_original_map NONE
# 394
# normalized_original_map NONE
# 395
# normalized_original_map NONE
# 396
# normalized_original_map NONE
# 397
# normalized_original_map NONE
# 398
# normalized_original_map NONE
# 399
# normalized_original_map NONE
# 400
# normalized_original_map NONE
# 401
# normalized_original_map NONE
# 402
# normalized_original_map NONE
# 403
# normalized_original_map NONE
# 404
# normalized_original_map NONE
# 405
# normalized_original_map NONE
# 406
# normalized_original_map NONE
# 407
# normalized_original_map NONE
# 408
# normalized_original_map NONE
# 409
# normalized_original_map NONE
# 410
# normalized_original_map NONE
# 411
# normalized_original_map NONE
# 412
# normalized_original_map NONE
# 413
# normalized_original_map NONE
# 414
# normalized_original_map NONE
# 415
# normalized_original_map NONE
# 416
# normalized_original_map NONE
# 417
# normalized_original_map NONE
# 418
# normalized_original_map NONE
# 419
# normalized_original_map NONE
# 420
# normalized_original_map NONE
# 421
# normalized_original_map NONE
# 422
# normalized_original_map NONE
# 423
# normalized_original_map NONE
# 424
# normalized_original_map NONE
# 425
# normalized_original_map NONE
# 426
# normalized_original_map NONE
# 427
# normalized_original_map NONE
# 428
# normalized_original_map NONE
# 429
# normalized_original_map NONE
# 430
# normalized_original_map NONE
# 431
# normalized_original_map NONE
# 432
# normalized_original_map NONE
# 433
# normalized_original_map NONE
# 434
# normalized_original_map NONE
# 435
# normalized_original_map NONE
# 436
# normalized_original_map NONE
# 437
# normalized_original_map NONE
# 438
# normalized_original_map NONE
# 439
# normalized_original_map NONE
# 440
# normalized_original_map NONE
# 441
# normalized_original_map NONE
# 442
# normalized_original_map NONE
# 443
# normalized_original_map NONE
# 444
# normalized_original_map NONE
# 445
# normalized_original_map NONE
# 446
# normalized_original_map NONE
# 447
# normalized_original_map NONE
# 448
# normalized_original_map NONE
# 449
# normalized_original_map NONE
# 450
# normalized_original_map NONE
# 451
# normalized_original_map NONE
# 452
# normalized_original_map NONE
# 453
# normalized_original_map NONE
# 454
# normalized_original_map NONE
# 455
# normalized_original_map NONE
# 456
# normalized_original_map NONE
# 457
# normalized_original_map NONE
# 458
# normalized_original_map NONE
# 459
# normalized_original_map NONE
# 460
# normalized_original_map NONE
# 461
# normalized_original_map NONE
# 462
# normalized_original_map NONE
# 463
# normalized_original_map NONE
# 464
# normalized_original_map NONE
# 465
# normalized_original_map NONE
# 466
# normalized_original_map NONE
# 467
# normalized_original_map NONE
# 468
# normalized_original_map NONE
# 469
# normalized_original_map NONE
# 470
# normalized_original_map NONE
# 471
# normalized_original_map NONE
# 472
# normalized_original_map NONE
# 473
# normalized_original_map NONE
# 474
# normalized_original_map NONE
# 475
# normalized_original_map NONE
# 476
# normalized_original_map NONE
# 477
# normalized_original_map NONE
# 478
# normalized_original_map NONE
# 479
# normalized_original_map NONE
# 480
# normalized_original_map NONE
# 481
# normalized_original_map NONE
# 482
# normalized_original_map NONE
# 483
# normalized_original_map NONE
# 484
# normalized_original_map NONE
# 485
# normalized_original_map NONE
# 486
# normalized_original_map NONE
# 487
# normalized_original_map NONE
# 488
# normalized_original_map NONE
# 489
# normalized_original_map NONE
# 490
# normalized_original_map NONE
# 491
# normalized_original_map NONE
# 492
# normalized_original_map NONE
# 493
# normalized_original_map NONE
# 494
# normalized_original_map NONE
# 495
# normalized_original_map NONE
# 496
# normalized_original_map NONE
# 497
# normalized_original_map NONE
# 498
# normalized_original_map NONE
# 499
# normalized_original_map NONE
# 500
# normalized_original_map NONE
# 501
# normalized_original_map NONE
# 502
# normalized_original_map NONE
# 503
# normalized_original_map NONE
# 504
# normalized_original_map NONE
# 505
# normalized_original_map NONE
# 506
# normalized_original_map NONE
# 507
# normalized_original_map NONE
# 508
# normalized_original_map NONE
# 509
# normalized_original_map NONE
# 510
# normalized_original_map NONE
# 511
# normalized_original_map NONE
# 512
# normalized_original_map NONE
# 513
# normalized_original_map NONE
# 514
# normalized_original_map NONE
# 515
# normalized_original_map NONE
# 516
# normalized_original_map NONE
# 517
# normalized_original_map NONE
# 518
# normalized_original_map NONE
# 519
# normalized_original_map NONE
# 520
# normalized_original_map NONE
# 521
# normalized_original_map NONE
# 522
# normalized_original_map NONE
# 523
# normalized_original_map NONE
# 524
# normalized_original_map NONE
# 525
# normalized_original_map NONE
# 526
# normalized_original_map NONE
# 527
# normalized_original_map NONE
# 528
# normalized_original_map NONE
# 529
# normalized_original_map NONE
# 530
# normalized_original_map NONE
# 531
# normalized_original_map NONE
# 532
# normalized_original_map NONE
# 533
# normalized_original_map NONE
# 534
# normalized_original_map NONE
# 535
# normalized_original_map NONE
# 536
# normalized_original_map NONE
# 537
# normalized_original_map NONE
# 538
# normalized_original_map NONE
# 539
# normalized_original_map NONE
# 540
# normalized_original_map NONE
# 541
# normalized_original_map NONE
# 542
# normalized_original_map NONE
# 543
# normalized_original_map NONE
# 544
# normalized_original_map NONE
# 545
# normalized_original_map NONE
# 546
# normalized_original_map NONE
# 547
# normalized_original_map NONE
# 548
# normalized_original_map NONE
# 549
# normalized_original_map NONE
# 550
# normalized_original_map NONE
# 551
# normalized_original_map NONE
# 552
# normalized_original_map NONE
# 553
# normalized_original_map NONE
# 554
# normalized_original_map NONE
# 555
# normalized_original_map NONE
# 556
# normalized_original_map NONE
# 557
# normalized_original_map NONE
# 558
# normalized_original_map NONE
# 559
# normalized_original_map NONE
# 560
# normalized_original_map NONE
# 561
# normalized_original_map NONE
# 562
# normalized_original_map NONE
# 563
# normalized_original_map NONE
# 564
# normalized_original_map NONE
# 565
# normalized_original_map NONE
# 566
# normalized_original_map NONE
# 567
# normalized_original_map NONE
# 568
# normalized_original_map NONE
# 569
# normalized_original_map NONE
# 570
# normalized_original_map NONE
# 571
# normalized_original_map NONE
# 572
# normalized_original_map NONE
# 573
# normalized_original_map NONE
# 574
# normalized_original_map NONE
# 575
# normalized_original_map NONE
# 576
# normalized_original_map NONE
# 577
# normalized_original_map NONE
# 578
# normalized_original_map NONE
# 579
# normalized_original_map NONE
# 580
# normalized_original_map NONE
# 581
# normalized_original_map NONE
# 582
# normalized_original_map NONE
# 583
# normalized_original_map NONE
# 584
# normalized_original_map NONE
# 585
# normalized_original_map NONE
# 586
# normalized_original_map NONE
# 587
# normalized_original_map NONE
# 588
# normalized_original_map NONE
# 589
# normalized_original_map NONE
# 590
# normalized_original_map NONE
# 591
# normalized_original_map NONE
# 592
# normalized_original_map NONE
# 593
# normalized_original_map NONE
# 594
# normalized_original_map NONE
# 595
# normalized_original_map NONE
# 596
# normalized_original_map NONE
# 597
# normalized_original_map NONE
# 598
# normalized_original_map NONE
# 599
# normalized_original_map NONE
# 600
# normalized_original_map NONE
# 601
# normalized_original_map NONE
# 602
# normalized_original_map NONE
# 603
# normalized_original_map NONE
# 604
# normalized_original_map NONE
# 605
# normalized_original_map NONE
# 606
# normalized_original_map NONE
# 607
# normalized_original_map NONE
# 608
# normalized_original_map NONE
# 609
# normalized_original_map NONE
# 610
# normalized_original_map NONE
# 611
# normalized_original_map NONE
# 612
# normalized_original_map NONE
# 613
# normalized_original_map NONE
# 614
# normalized_original_map NONE
# 615
# normalized_original_map NONE
# 616
# normalized_original_map NONE
# 617
# normalized_original_map NONE
# 618
# normalized_original_map NONE
# 619
# normalized_original_map NONE
# 620
# normalized_original_map NONE
# 621
# normalized_original_map NONE
# 622
# normalized_original_map NONE
# 623
# normalized_original_map NONE
# 624
# normalized_original_map NONE
# 625
# normalized_original_map NONE
# 626
# normalized_original_map NONE
# 627
# normalized_original_map NONE
# 628
# normalized_original_map NONE
# 629
# normalized_original_map NONE
# 630
# normalized_original_map NONE
# 631
# normalized_original_map NONE
# 632
# normalized_original_map NONE
# 633
# normalized_original_map NONE
# 634
# normalized_original_map NONE
# 635
# normalized_original_map NONE
# 636
# normalized_original_map NONE
# 637
# normalized_original_map NONE
# 638
# normalized_original_map NONE
# 639
# normalized_original_map NONE
# 640
# normalized_original_map NONE
# 641
# normalized_original_map NONE
# 642
# normalized_original_map NONE
# 643
# normalized_original_map NONE
# 644
# normalized_original_map NONE
# 645
# normalized_original_map NONE
# 646
# normalized_original_map NONE
# 647
# normalized_original_map NONE
# 648
# normalized_original_map NONE
# 649
# normalized_original_map NONE
# 650
# normalized_original_map NONE
# 651
# normalized_original_map NONE
# 652
# normalized_original_map NONE
# 653
# normalized_original_map NONE
# 654
# normalized_original_map NONE
# 655
# normalized_original_map NONE
# 656
# normalized_original_map NONE
# 657
# normalized_original_map NONE
# 658
# normalized_original_map NONE
# 659
# normalized_original_map NONE
# 660
# normalized_original_map NONE
# 661
# normalized_original_map NONE
# 662
# normalized_original_map NONE
# 663
# normalized_original_map NONE
# 664
# normalized_original_map NONE
# 665
# normalized_original_map NONE
# 666
# normalized_original_map NONE
# 667
# normalized_original_map NONE
# 668
# normalized_original_map NONE
# 669
# normalized_original_map NONE
# 670
# normalized_original_map NONE
# 671
# normalized_original_map NONE
# 672
# normalized_original_map NONE
# 673
# normalized_original_map NONE
# 674
# normalized_original_map NONE
# 675
# normalized_original_map NONE
# 676
# normalized_original_map NONE
# 677
# normalized_original_map NONE
# 678
# normalized_original_map NONE
# 679
# normalized_original_map NONE
# 680
# normalized_original_map NONE
# 681
# normalized_original_map NONE
# 682
# normalized_original_map NONE
# 683
# normalized_original_map NONE
# 684
# normalized_original_map NONE
# 685
# normalized_original_map NONE
# 686
# normalized_original_map NONE
# 687
# normalized_original_map NONE
# 688
# normalized_original_map NONE
# 689
# normalized_original_map NONE
# 690
# normalized_original_map NONE
# 691
# normalized_original_map NONE
# 692
# normalized_original_map NONE
# 693
# normalized_original_map NONE
# 694
# normalized_original_map NONE
# 695
# normalized_original_map NONE
# 696
# normalized_original_map NONE
# 697
# normalized_original_map NONE
# 698
# normalized_original_map NONE
# 699
# normalized_original_map NONE
# 700
# normalized_original_map NONE
# 701
# normalized_original_map NONE
# 702
# normalized_original_map NONE
# 703
# normalized_original_map NONE
# 704
# normalized_original_map NONE
# 705
# normalized_original_map NONE
# 706
# normalized_original_map NONE
# 707
# normalized_original_map NONE
# 708
# normalized_original_map NONE
# 709
# normalized_original_map NONE
# 710
# normalized_original_map NONE
# 711
# normalized_original_map NONE
# 712
# normalized_original_map NONE
# 713
# normalized_original_map NONE
# 714
# normalized_original_map NONE
# 715
# normalized_original_map NONE
# 716
# normalized_original_map NONE
# 717
# normalized_original_map NONE
# 718
# normalized_original_map NONE
# 719
# normalized_original_map NONE
# 720
# normalized_original_map NONE
# 721
# normalized_original_map NONE
# 722
# normalized_original_map NONE
# 723
# normalized_original_map NONE
# 724
# normalized_original_map NONE
# 725
# normalized_original_map NONE
# 726
# normalized_original_map NONE
# 727
# normalized_original_map NONE
# 728
# normalized_original_map NONE
# 729
# normalized_original_map NONE
# 730
# normalized_original_map NONE
# 731
# normalized_original_map NONE
# 732
# normalized_original_map NONE
# 733
# normalized_original_map NONE
# 734
# normalized_original_map NONE
# 735
# normalized_original_map NONE
# 736
# normalized_original_map NONE
# 737
# normalized_original_map NONE
# 738
# normalized_original_map NONE
# 739
# normalized_original_map NONE
# 740
# normalized_original_map NONE
# 741
# normalized_original_map NONE
# 742
# normalized_original_map NONE
# 743
# normalized_original_map NONE
# 744
# normalized_original_map NONE
# 745
# normalized_original_map NONE
# 746
# normalized_original_map NONE
# 747
# normalized_original_map NONE
# 748
# normalized_original_map NONE
# 749
# normalized_original_map NONE
# 750
# normalized_original_map NONE
# 751
# normalized_original_map NONE
# 752
# normalized_original_map NONE
# 753
# normalized_original_map NONE
# 754
# normalized_original_map NONE
# 755
# normalized_original_map NONE
# 756
# normalized_original_map NONE
# 757
# normalized_original_map NONE
# 758
# normalized_original_map NONE
# 759
# normalized_original_map NONE
# 760
# normalized_original_map NONE
# 761
# normalized_original_map NONE
# 762
# normalized_original_map NONE
# 763
# normalized_original_map NONE
# 764
# normalized_original_map NONE
# 765
# normalized_original_map NONE
# 766
# normalized_original_map NONE
# 767
# normalized_original_map NONE
# 768
# normalized_original_map NONE
# 769
# normalized_original_map NONE
# 770
# normalized_original_map NONE
# 771
# normalized_original_map NONE
# 772
# normalized_original_map NONE
# 773
# normalized_original_map NONE
# 774
# normalized_original_map NONE
# 775
# normalized_original_map NONE
# 776
# normalized_original_map NONE
# 777
# normalized_original_map NONE
# 778
# normalized_original_map NONE
# 779
# normalized_original_map NONE
# 780
# normalized_original_map NONE
# 781
# normalized_original_map NONE
# 782
# normalized_original_map NONE
# 783
# normalized_original_map NONE
# 784
# normalized_original_map NONE
# 785
# normalized_original_map NONE
# 786
# normalized_original_map NONE
# 787
# normalized_original_map NONE
# 788
# normalized_original_map NONE
# 789
# normalized_original_map NONE
# 790
# normalized_original_map NONE
# 791
# normalized_original_map NONE
# 792
# normalized_original_map NONE
# 793
# normalized_original_map NONE
# 794
# normalized_original_map NONE
# 795
# normalized_original_map NONE
# 796
# normalized_original_map NONE
# 797
# normalized_original_map NONE
# 798
# normalized_original_map NONE
# 799
# normalized_original_map NONE
# 800
# normalized_original_map NONE
# 801
# normalized_original_map NONE
# 802
# normalized_original_map NONE
# 803
# normalized_original_map NONE
# 804
# normalized_original_map NONE
# 805
# normalized_original_map NONE
# 806
# normalized_original_map NONE
# 807
# normalized_original_map NONE
# 808
# normalized_original_map NONE
# 809
# normalized_original_map NONE
# 810
# normalized_original_map NONE
# 811
# normalized_original_map NONE
# 812
# normalized_original_map NONE
# 813
# normalized_original_map NONE
# 814
# normalized_original_map NONE
# 815
# normalized_original_map NONE
# 816
# normalized_original_map NONE
# 817
# normalized_original_map NONE
# 818
# normalized_original_map NONE
# 819
# normalized_original_map NONE
# 820
# normalized_original_map NONE
# 821
# normalized_original_map NONE
# 822
# normalized_original_map NONE
# 823
# normalized_original_map NONE
# 824
# normalized_original_map NONE
# 825
# normalized_original_map NONE
# 826
# normalized_original_map NONE
# 827
# normalized_original_map NONE
# 828
# normalized_original_map NONE
# 829
# normalized_original_map NONE
# 830
# normalized_original_map NONE
# 831
# normalized_original_map NONE
# 832
# normalized_original_map NONE
# 833
# normalized_original_map NONE
# 834
# normalized_original_map NONE
# 835
# normalized_original_map NONE
# 836
# normalized_original_map NONE
# 837
# normalized_original_map NONE
# 838
# normalized_original_map NONE
# 839
# normalized_original_map NONE
# 840
# normalized_original_map NONE
# 841
# normalized_original_map NONE
# 842
# normalized_original_map NONE
# 843
# normalized_original_map NONE
# 844
# normalized_original_map NONE
# 845
# normalized_original_map NONE
# 846
# normalized_original_map NONE
# 847
# normalized_original_map NONE
# 848
# normalized_original_map NONE
# 849
# normalized_original_map NONE
# 850
# normalized_original_map NONE
# 851
# normalized_original_map NONE
# 852
# normalized_original_map NONE
# 853
# normalized_original_map NONE
# 854
# normalized_original_map NONE
# 855
# normalized_original_map NONE
# 856
# normalized_original_map NONE
# 857
# normalized_original_map NONE
# 858
# normalized_original_map NONE
# 859
# normalized_original_map NONE
# 860
# normalized_original_map NONE
# 861
# normalized_original_map NONE
# 862
# normalized_original_map NONE
# 863
# normalized_original_map NONE
# 864
# normalized_original_map NONE
# 865
# normalized_original_map NONE
# 866
# normalized_original_map NONE
# 867
# normalized_original_map NONE
# 868
# normalized_original_map NONE
# 869
# normalized_original_map NONE
# 870
# normalized_original_map NONE
# 871
# normalized_original_map NONE
# 872
# normalized_original_map NONE
# 873
# normalized_original_map NONE
# 874
# normalized_original_map NONE
# 875
# normalized_original_map NONE
# 876
# normalized_original_map NONE
# 877
# normalized_original_map NONE
# 878
# normalized_original_map NONE
# 879
# normalized_original_map NONE
# 880
# normalized_original_map NONE
# 881
# normalized_original_map NONE
# 882
# normalized_original_map NONE
# 883
# normalized_original_map NONE
# 884
# normalized_original_map NONE
# 885
# normalized_original_map NONE
# 886
# normalized_original_map NONE
# 887
# normalized_original_map NONE
# 888
# normalized_original_map NONE
# 889
# normalized_original_map NONE
# 890
# normalized_original_map NONE
# 891
# normalized_original_map NONE
# 892
# normalized_original_map NONE
# 893
# normalized_original_map NONE
# 894
# normalized_original_map NONE
# 895
# normalized_original_map NONE
# 896
# normalized_original_map NONE
# 897
# normalized_original_map NONE
# 898
# normalized_original_map NONE
# 899
# normalized_original_map NONE
# 900
# normalized_original_map NONE
# 901
# normalized_original_map NONE
# 902
# normalized_original_map NONE
# 903
# normalized_original_map NONE
# 904
# normalized_original_map NONE
# 905
# normalized_original_map NONE
# 906
# normalized_original_map NONE
# 907
# normalized_original_map NONE
# 908
# normalized_original_map NONE
# 909
# normalized_original_map NONE
# 910
# normalized_original_map NONE
# 911
# normalized_original_map NONE
# 912
# normalized_original_map NONE
# 913
# normalized_original_map NONE
# 914
# normalized_original_map NONE
# 915
# normalized_original_map NONE
# 916
# normalized_original_map NONE
# 917
# normalized_original_map NONE
# 918
# normalized_original_map NONE
# 919
# normalized_original_map NONE
# 920
# normalized_original_map NONE
# 921
# normalized_original_map NONE
# 922
# normalized_original_map NONE
# 923
# normalized_original_map NONE
# 924
# normalized_original_map NONE
# 925
# normalized_original_map NONE
# 926
# normalized_original_map NONE
# 927
# normalized_original_map NONE
# 928
# normalized_original_map NONE
# 929
# normalized_original_map NONE
# 930
# normalized_original_map NONE
# 931
# normalized_original_map NONE
# 932
# normalized_original_map NONE
# 933
# normalized_original_map NONE
# 934
# normalized_original_map NONE
# 935
# normalized_original_map NONE
# 936
# normalized_original_map NONE
# 937
# normalized_original_map NONE
# 938
# normalized_original_map NONE
# 939
# normalized_original_map NONE
# 940
# normalized_original_map NONE
# 941
# normalized_original_map NONE
# 942
# normalized_original_map NONE
# 943
# normalized_original_map NONE
# 944
# normalized_original_map NONE
# 945
# normalized_original_map NONE
# 946
# normalized_original_map NONE
# 947
# normalized_original_map NONE
# 948
# normalized_original_map NONE
# 949
# normalized_original_map NONE
# 950
# normalized_original_map NONE
# 951
# normalized_original_map NONE
# 952
# normalized_original_map NONE
# 953
# normalized_original_map NONE
# 954
# normalized_original_map NONE
# 955
# normalized_original_map NONE
# 956
# normalized_original_map NONE
# 957
# normalized_original_map NONE
# 958
# normalized_original_map NONE
# 959
# normalized_original_map NONE
# 960
# normalized_original_map NONE
# 961
# normalized_original_map NONE
# 962
# normalized_original_map NONE
# 963
# normalized_original_map NONE
# 964
# normalized_original_map NONE
# 965
# normalized_original_map NONE
# 966
# normalized_original_map NONE
# 967
# normalized_original_map NONE
# 968
# normalized_original_map NONE
# 969
# normalized_original_map NONE
# 970
# normalized_original_map NONE
# 971
# normalized_original_map NONE
# 972
# normalized_original_map NONE
# 973
# normalized_original_map NONE
# 974
# normalized_original_map NONE
# 975
# normalized_original_map NONE
# 976
# normalized_original_map NONE
# 977
# normalized_original_map NONE
# 978
# normalized_original_map NONE
# 979
# normalized_original_map NONE
# 980
# normalized_original_map NONE
# 981
# normalized_original_map NONE
# 982
# normalized_original_map NONE
# 983
# normalized_original_map NONE
# 984
# normalized_original_map NONE
# 985
# normalized_original_map NONE
# 986
# normalized_original_map NONE
# 987
# normalized_original_map NONE
# 988
# normalized_original_map NONE
# 989
# normalized_original_map NONE
# 990
# normalized_original_map NONE
# 991
# normalized_original_map NONE
# 992
# normalized_original_map NONE
# 993
# normalized_original_map NONE
# 994
# normalized_original_map NONE
# 995
# normalized_original_map NONE
# 996
# normalized_original_map NONE
# 997
# normalized_original_map NONE
# 998
# normalized_original_map NONE
# 999
# normalized_original_map NONE
# 1000
# normalized_original_map NONE
# 1001
# normalized_original_map NONE
# 1002
# normalized_original_map NONE
# 1003
# normalized_original_map NONE
# 1004
# normalized_original_map NONE
# 1005
# normalized_original_map NONE
# 1006
# normalized_original_map NONE
# 1007
# normalized_original_map NONE
# 1008
# normalized_original_map NONE
# 1009
# normalized_original_map NONE
# 1010
# normalized_original_map NONE
# 1011
# normalized_original_map NONE
# 1012
# normalized_original_map NONE
# 1013
# normalized_original_map NONE
# 1014
# normalized_original_map NONE
# 1015
# normalized_original_map NONE
# 1016
# normalized_original_map NONE
# 1017
# normalized_original_map NONE
# 1018
# normalized_original_map NONE
# 1019
# normalized_original_map NONE
# 1020
# normalized_original_map NONE
# 1021
# normalized_original_map NONE
# 1022
# normalized_original_map NONE
# 1023
# normalized_original_map NONE
# 1024
# normalized_original_map NONE
# 1025
# normalized_original_map NONE
# 1026
# normalized_original_map NONE
# 1027
# normalized_original_map NONE
# 1028
# normalized_original_map NONE
# 1029
# normalized_original_map NONE
# 1030
# normalized_original_map NONE
# 1031
# normalized_original_map NONE
# 1032
# normalized_original_map NONE
# 1033
# normalized_original_map NONE
# 1034
# normalized_original_map NONE
# 1035
# normalized_original_map NONE
# 1036
# normalized_original_map NONE
# 1037
# normalized_original_map NONE
# 1038
# normalized_original_map NONE
# 1039
# normalized_original_map NONE
# 1040
# normalized_original_map NONE
# 1041
# normalized_original_map NONE
# 1042
# normalized_original_map NONE
# 1043
# normalized_original_map NONE
# 1044
# normalized_original_map NONE
# 1045
# normalized_original_map NONE
# 1046
# normalized_original_map NONE
# 1047
# normalized_original_map NONE
# 1048
# normalized_original_map NONE
# 1049
# normalized_original_map NONE
# 1050
# normalized_original_map NONE
# 1051
# normalized_original_map NONE
# 1052
# normalized_original_map NONE
# 1053
# normalized_original_map NONE
# 1054
# normalized_original_map NONE
# 1055
# normalized_original_map NONE
# 1056
# normalized_original_map NONE
# 1057
# normalized_original_map NONE
# 1058
# normalized_original_map NONE
# 1059
# normalized_original_map NONE
# 1060
# normalized_original_map NONE
# 1061
# normalized_original_map NONE
# 1062
# normalized_original_map NONE
# 1063
# normalized_original_map NONE
# 1064
# normalized_original_map NONE
# 1065
# normalized_original_map NONE
# 1066
# normalized_original_map NONE
# 1067
# normalized_original_map NONE
# 1068
# normalized_original_map NONE
# 1069
# normalized_original_map NONE
# 1070
# normalized_original_map NONE
# 1071
# normalized_original_map NONE
# 1072
# normalized_original_map NONE
# 1073
# normalized_original_map NONE
# 1074
# normalized_original_map NONE
# 1075
# normalized_original_map NONE
# 1076
# normalized_original_map NONE
# 1077
# normalized_original_map NONE
# 1078
# normalized_original_map NONE
# 1079
# normalized_original_map NONE
# 1080
# normalized_original_map NONE
# 1081
# normalized_original_map NONE
# 1082
# normalized_original_map NONE
# 1083
# normalized_original_map NONE
# 1084
# normalized_original_map NONE
# 1085
# normalized_original_map NONE
# 1086
# normalized_original_map NONE
# 1087
# normalized_original_map NONE
# 1088
# normalized_original_map NONE
# 1089
# normalized_original_map NONE
# 1090
# normalized_original_map NONE
# 1091
# normalized_original_map NONE
# 1092
# normalized_original_map NONE
# 1093
# normalized_original_map NONE
# 1094
# normalized_original_map NONE
# 1095
# normalized_original_map NONE
# 1096
# normalized_original_map NONE
# 1097
# normalized_original_map NONE
# 1098
# normalized_original_map NONE
# 1099
# normalized_original_map NONE
# 1100
# normalized_original_map NONE
# 1101
# normalized_original_map NONE
# 1102
# normalized_original_map NONE
# 1103
# normalized_original_map NONE
# 1104
# normalized_original_map NONE
# 1105
# normalized_original_map NONE
# 1106
# normalized_original_map NONE
# 1107
# normalized_original_map NONE
# 1108
# normalized_original_map NONE
# 1109
# normalized_original_map NONE
# 1110
# normalized_original_map NONE
# 1111
# normalized_original_map NONE
# 1112
# normalized_original_map NONE
# 1113
# normalized_original_map NONE
# 1114
# normalized_original_map NONE
# 1115
# normalized_original_map NONE
# 1116
# normalized_original_map NONE
# 1117
# normalized_original_map NONE
# 1118
# normalized_original_map NONE
# 1119
# normalized_original_map NONE
# 1120
# normalized_original_map NONE
# 1121
# normalized_original_map NONE
# 1122
# normalized_original_map NONE
# 1123
# normalized_original_map NONE
# 1124
# normalized_original_map NONE
# 1125
# normalized_original_map NONE
# 1126
# normalized_original_map NONE
# 1127
# normalized_original_map NONE
# 1128
# normalized_original_map NONE
# 1129
# normalized_original_map NONE
# 1130
# normalized_original_map NONE
# 1131
# normalized_original_map NONE
# 1132
# normalized_original_map NONE
# 1133
# normalized_original_map NONE
# 1134
# normalized_original_map NONE
# 1135
# normalized_original_map NONE
# 1136
# normalized_original_map NONE
# 1137
# normalized_original_map NONE
# 1138
# normalized_original_map NONE
# 1139
# normalized_original_map NONE
# 1140
# normalized_original_map NONE
# 1141
# normalized_original_map NONE
# 1142
# normalized_original_map NONE
# 1143
# normalized_original_map NONE
# 1144
# normalized_original_map NONE
# 1145
# normalized_original_map NONE
# 1146
# normalized_original_map NONE
# 1147
# normalized_original_map NONE
# 1148
# normalized_original_map NONE
# 1149
# normalized_original_map NONE
# 1150
# normalized_original_map NONE
# 1151
# normalized_original_map NONE
# 1152
# normalized_original_map NONE
# 1153
# normalized_original_map NONE
# 1154
# normalized_original_map NONE
# 1155
# normalized_original_map NONE
# 1156
# normalized_original_map NONE
# 1157
# normalized_original_map NONE
# 1158
# normalized_original_map NONE
# 1159
# normalized_original_map NONE
# 1160
# normalized_original_map NONE
# 1161
# normalized_original_map NONE
# 1162
# normalized_original_map NONE
# 1163
# normalized_original_map NONE
# 1164
# normalized_original_map NONE
# 1165
# normalized_original_map NONE
# 1166
# normalized_original_map NONE
# 1167
# normalized_original_map NONE
# 1168
# normalized_original_map NONE
# 1169
# normalized_original_map NONE
# 1170
# normalized_original_map NONE
# 1171
# normalized_original_map NONE
# 1172
# normalized_original_map NONE
# 1173
# normalized_original_map NONE
# 1174
# normalized_original_map NONE
# 1175
# normalized_original_map NONE
# 1176
# normalized_original_map NONE
# 1177
# normalized_original_map NONE
# 1178
# normalized_original_map NONE
# 1179
# normalized_original_map NONE
# 1180
# normalized_original_map NONE
# 1181
# normalized_original_map NONE
# 1182
# normalized_original_map NONE
# 1183
# normalized_original_map NONE
# 1184
# normalized_original_map NONE
# 1185
# normalized_original_map NONE
# 1186
# normalized_original_map NONE
# 1187
# normalized_original_map NONE
# 1188
# normalized_original_map NONE
# 1189
# normalized_original_map NONE
# 1190
# normalized_original_map NONE
# 1191
# normalized_original_map NONE
# 1192
# normalized_original_map NONE
# 1193
# normalized_original_map NONE
# 1194
# normalized_original_map NONE
# 1195
# normalized_original_map NONE
# 1196
# normalized_original_map NONE
# 1197
# normalized_original_map NONE
# 1198
# normalized_original_map NONE
# 1199
# normalized_original_map NONE
# 1200
# normalized_original_map NONE
# 1201
# normalized_original_map NONE
# 1202
# normalized_original_map NONE
# 1203
# normalized_original_map NONE
# 1204
# normalized_original_map NONE
# 1205
# normalized_original_map NONE
# 1206
# normalized_original_map NONE
# 1207
# normalized_original_map NONE
# 1208
# normalized_original_map NONE
# 1209
# normalized_original_map NONE
# 1210
# normalized_original_map NONE
# 1211
# normalized_original_map NONE
# 1212
# normalized_original_map NONE
# 1213
# normalized_original_map NONE
# 1214
# normalized_original_map NONE
# 1215
# normalized_original_map NONE
# 1216
# normalized_original_map NONE
# 1217
# normalized_original_map NONE
# 1218
# normalized_original_map NONE
# 1219
# normalized_original_map NONE
# 1220
# normalized_original_map NONE
# 1221
# normalized_original_map NONE
# 1222
# normalized_original_map NONE
# 1223
# normalized_original_map NONE
# 1224
# normalized_original_map NONE
# 1225
# normalized_original_map NONE
# 1226
# normalized_original_map NONE
# 1227
# normalized_original_map NONE
# 1228
# normalized_original_map NONE
# 1229
# normalized_original_map NONE
# 1230
# normalized_original_map NONE
# 1231
# normalized_original_map NONE
# 1232
# normalized_original_map NONE
# 1233
# normalized_original_map NONE
# 1234
# normalized_original_map NONE
# 1235
# normalized_original_map NONE
# 1236
# normalized_original_map NONE
# 1237
# normalized_original_map NONE
# 1238
# normalized_original_map NONE
# 1239
# normalized_original_map NONE
# 1240
# normalized_original_map NONE
# 1241
# normalized_original_map NONE
# 1242
# normalized_original_map NONE
# 1243
# normalized_original_map NONE
# 1244
# normalized_original_map NONE
# 1245
# normalized_original_map NONE
# 1246
# normalized_original_map NONE
# 1247
# normalized_original_map NONE
# 1248
# normalized_original_map NONE
# 1249
# normalized_original_map NONE
# 1250
# normalized_original_map NONE
# 1251
# normalized_original_map NONE
# 1252
# normalized_original_map NONE
# 1253
# normalized_original_map NONE
# 1254
# normalized_original_map NONE
# 1255
# normalized_original_map NONE
# 1256
# normalized_original_map NONE
# 1257
# normalized_original_map NONE
# 1258
# normalized_original_map NONE
# 1259
# normalized_original_map NONE
# 1260
# normalized_original_map NONE
# 1261
# normalized_original_map NONE
# 1262
# normalized_original_map NONE
# 1263
# normalized_original_map NONE
# 1264
# normalized_original_map NONE
# 1265
# normalized_original_map NONE
# 1266
# normalized_original_map NONE
# 1267
# normalized_original_map NONE
# 1268
# normalized_original_map NONE
# 1269
# normalized_original_map NONE
# 1270
# normalized_original_map NONE
# 1271
# normalized_original_map NONE
# 1272
# normalized_original_map NONE
# 1273
# normalized_original_map NONE
# 1274
# normalized_original_map NONE
# 1275
# normalized_original_map NONE
# 1276
# normalized_original_map NONE
# 1277
# normalized_original_map NONE
# 1278
# normalized_original_map NONE
# 1279
# normalized_original_map NONE
# 1280
# normalized_original_map NONE
# 1281
# normalized_original_map NONE
# 1282
# normalized_original_map NONE
# 1283
# normalized_original_map NONE
# 1284
# normalized_original_map NONE
# 1285
# normalized_original_map NONE
# 1286
# normalized_original_map NONE
# 1287
# normalized_original_map NONE
# 1288
# normalized_original_map NONE
# 1289
# normalized_original_map NONE
# 1290
# normalized_original_map NONE
# 1291
# normalized_original_map NONE
# 1292
# normalized_original_map NONE
# 1293
# normalized_original_map NONE
# 1294
# normalized_original_map NONE
# 1295
# normalized_original_map NONE
# 1296
# normalized_original_map NONE
# 1297
# normalized_original_map NONE
# 1298
# normalized_original_map NONE
# 1299
# normalized_original_map NONE
# 1300
# normalized_original_map NONE
# 1301
# normalized_original_map NONE
# 1302
# normalized_original_map NONE
# 1303
# normalized_original_map NONE
# 1304
# normalized_original_map NONE
# 1305
# normalized_original_map NONE
# 1306
# normalized_original_map NONE
# 1307
# normalized_original_map NONE
# 1308
# normalized_original_map NONE
# 1309
# normalized_original_map NONE
# 1310
# normalized_original_map NONE
# 1311
# normalized_original_map NONE
# 1312
# normalized_original_map NONE
# 1313
# normalized_original_map NONE
# 1314
# normalized_original_map NONE
# 1315
# normalized_original_map NONE
# 1316
# normalized_original_map NONE
# 1317
# normalized_original_map NONE
# 1318
# normalized_original_map NONE
# 1319
# normalized_original_map NONE
# 1320
# normalized_original_map NONE
# 1321
# normalized_original_map NONE
# 1322
# normalized_original_map NONE
# 1323
# normalized_original_map NONE
# 1324
# normalized_original_map NONE
# 1325
# normalized_original_map NONE
# 1326
# normalized_original_map NONE
# 1327
# normalized_original_map NONE
# 1328
# normalized_original_map NONE
# 1329
# normalized_original_map NONE
# 1330
# normalized_original_map NONE
# 1331
# normalized_original_map NONE
# 1332
# normalized_original_map NONE
# 1333
# normalized_original_map NONE
# 1334
# normalized_original_map NONE
# 1335
# normalized_original_map NONE
# 1336
# normalized_original_map NONE
# 1337
# normalized_original_map NONE
# 1338
# normalized_original_map NONE
# 1339
# normalized_original_map NONE
# 1340
# normalized_original_map NONE
# 1341
# normalized_original_map NONE
# 1342
# normalized_original_map NONE
# 1343
# normalized_original_map NONE
# 1344
# normalized_original_map NONE
# 1345
# normalized_original_map NONE
# 1346
# normalized_original_map NONE
# 1347
# normalized_original_map NONE
# 1348
# normalized_original_map NONE
# 1349
# normalized_original_map NONE
# 1350
# normalized_original_map NONE
# 1351
# normalized_original_map NONE
# 1352
# normalized_original_map NONE
# 1353
# normalized_original_map NONE
# 1354
# normalized_original_map NONE
# 1355
# normalized_original_map NONE
# 1356
# normalized_original_map NONE
# 1357
# normalized_original_map NONE
# 1358
# normalized_original_map NONE
# 1359
# normalized_original_map NONE
# 1360
# normalized_original_map NONE
# 1361
# normalized_original_map NONE
# 1362
# normalized_original_map NONE
# 1363
# normalized_original_map NONE
# 1364
# normalized_original_map NONE
# 1365
# normalized_original_map NONE
# 1366
# normalized_original_map NONE
# 1367
# normalized_original_map NONE
# 1368
# normalized_original_map NONE
# 1369
# normalized_original_map NONE
# 1370
# normalized_original_map NONE
# 1371
# normalized_original_map NONE
# 1372
# normalized_original_map NONE
# 1373
# normalized_original_map NONE
# 1374
# normalized_original_map NONE
# 1375
# normalized_original_map NONE
# 1376
# normalized_original_map NONE
# 1377
# normalized_original_map NONE
# 1378
# normalized_original_map NONE
# 1379
# normalized_original_map NONE
# 1380
# normalized_original_map NONE
# 1381
# normalized_original_map NONE
# 1382
# normalized_original_map NONE
# 1383
# normalized_original_map NONE
# 1384
# normalized_original_map NONE
# 1385
# normalized_original_map NONE
# 1386
# normalized_original_map NONE
# 1387
# normalized_original_map NONE
# 1388
# normalized_original_map NONE
# 1389
# normalized_original_map NONE
# 1390
# normalized_original_map NONE
# 1391
# normalized_original_map NONE
# 1392
# normalized_original_map NONE
# 1393
# normalized_original_map NONE
# 1394
# normalized_original_map NONE
# 1395
# normalized_original_map NONE
# 1396
# normalized_original_map NONE
# 1397
# normalized_original_map NONE
# 1398
# normalized_original_map NONE
# 1399
# normalized_original_map NONE
# 1400
# normalized_original_map NONE
# 1401
# normalized_original_map NONE
# 1402
# normalized_original_map NONE
# 1403
# normalized_original_map NONE
# 1404
# normalized_original_map NONE
# 1405
# normalized_original_map NONE
# 1406
# normalized_original_map NONE
# 1407
# normalized_original_map NONE
# 1408
# normalized_original_map NONE
# 1409
# normalized_original_map NONE
# 1410
# normalized_original_map NONE
# 1411
# normalized_original_map NONE
# 1412
# normalized_original_map NONE
# 1413
# normalized_original_map NONE
# 1414
# normalized_original_map NONE
# 1415
# normalized_original_map NONE
# 1416
# normalized_original_map NONE
# 1417
# normalized_original_map NONE
# 1418
# normalized_original_map NONE
# 1419
# normalized_original_map NONE
# 1420
# normalized_original_map NONE
# 1421
# normalized_original_map NONE
# 1422
# normalized_original_map NONE
# 1423
# normalized_original_map NONE
# 1424
# normalized_original_map NONE
# 1425
# normalized_original_map NONE
# 1426
# normalized_original_map NONE
# 1427
# normalized_original_map NONE
# 1428
# normalized_original_map NONE
# 1429
# normalized_original_map NONE
# 1430
# normalized_original_map NONE
# 1431
# normalized_original_map NONE
# 1432
# normalized_original_map NONE
# 1433
# normalized_original_map NONE
# 1434
# normalized_original_map NONE
# 1435
# normalized_original_map NONE
# 1436
# normalized_original_map NONE
# 1437
# normalized_original_map NONE
# 1438
# normalized_original_map NONE
# 1439
# normalized_original_map NONE
# 1440
# normalized_original_map NONE
# 1441
# normalized_original_map NONE
# 1442
# normalized_original_map NONE
# 1443
# normalized_original_map NONE
# 1444
# ...
# 2589
# normalized_original_map NONE
# 2590
# normalized_original_map NONE
# 2591
# normalized_original_map NONE
# 2592
# normalized_original_map NONE
# 2593
# normalized_original_map NONE
# 2594
# normalized_original_map NONE
# 2595
# normalized_original_map NONE
# 2596
# normalized_original_map NONE
# 2597
# normalized_original_map NONE
# 2598
# normalized_original_map NONE
# 2599
# normalized_original_map NONE
# 2600
# normalized_original_map NONE
# 2601
# normalized_original_map NONE
# 2602
# normalized_original_map NONE
# 2603
# normalized_original_map NONE
# 2604
# normalized_original_map NONE
# 2605
# normalized_original_map NONE
# 2606
# normalized_original_map NONE
# 2607
# normalized_original_map NONE
# 2608
# normalized_original_map NONE
# 2609
# normalized_original_map NONE
# 2610
# normalized_original_map NONE
# 2611
# normalized_original_map NONE
# 2612
# normalized_original_map NONE
# 2613
# normalized_original_map NONE
# 2614
# normalized_original_map NONE
# 2615
# normalized_original_map NONE
# 2616
# normalized_original_map NONE
# 2617
# normalized_original_map NONE
# 2618
# normalized_original_map NONE
# 2619
# normalized_original_map NONE
# 2620
# normalized_original_map NONE
# 2621
# normalized_original_map NONE
# 2622
# normalized_original_map NONE
# 2623
# normalized_original_map NONE
# 2624
# normalized_original_map NONE
# 2625
# normalized_original_map NONE
# 2626
# normalized_original_map NONE
# 2627
# normalized_original_map NONE
# 2628
# normalized_original_map NONE
# 2629
# normalized_original_map NONE
# 2630
# normalized_original_map NONE
# 2631
# normalized_original_map NONE
# 2632
# normalized_original_map NONE
# 2633
# normalized_original_map NONE
# 2634
# normalized_original_map NONE
# 2635
# normalized_original_map NONE
# 2636
# normalized_original_map NONE
# 2637
# normalized_original_map NONE
# 2638
# normalized_original_map NONE
# 2639
# normalized_original_map NONE
# 2640
# normalized_original_map NONE
# 2641
# normalized_original_map NONE
# 2642
# normalized_original_map NONE
# 2643
# normalized_original_map NONE
# 2644
# normalized_original_map NONE
# 2645
# normalized_original_map NONE
# 2646
# normalized_original_map NONE
# 2647
# normalized_original_map NONE
# 2648
# normalized_original_map NONE
# 2649
# normalized_original_map NONE
# 2650
# normalized_original_map NONE
# 2651
# normalized_original_map NONE
# 2652
# normalized_original_map NONE
# 2653
# normalized_original_map NONE
# 2654
# normalized_original_map NONE
# 2655
# normalized_original_map NONE
# 2656
# normalized_original_map NONE
# 2657
# normalized_original_map NONE
# 2658
# normalized_original_map NONE
# 2659
# normalized_original_map NONE
# 2660
# normalized_original_map NONE
# 2661
# normalized_original_map NONE
# 2662
# normalized_original_map NONE
# 2663
# normalized_original_map NONE
# 2664
# normalized_original_map NONE
# 2665
# normalized_original_map NONE
# 2666
# normalized_original_map NONE
# 2667
# normalized_original_map NONE
# 2668
# normalized_original_map NONE
# 2669
# normalized_original_map NONE
# 2670
# normalized_original_map NONE
# 2671
# normalized_original_map NONE
# 2672
# normalized_original_map NONE
# 2673
# normalized_original_map NONE
# 2674
# normalized_original_map NONE
# 2675
# normalized_original_map NONE
# 2676
# normalized_original_map NONE
# 2677
# normalized_original_map NONE
# 2678
# normalized_original_map NONE
# 2679
# normalized_original_map NONE
# 2680
# normalized_original_map NONE
# 2681
# normalized_original_map NONE
# 2682
# normalized_original_map NONE
# 2683
# normalized_original_map NONE
# 2684
# normalized_original_map NONE
# 2685
# normalized_original_map NONE
# 2686
# normalized_original_map NONE
# 2687
# normalized_original_map NONE
# 2688
# normalized_original_map NONE
# 2689
# normalized_original_map NONE
# 2690
# normalized_original_map NONE
# 2691
# normalized_original_map NONE
# 2692
# normalized_original_map NONE
# 2693
# normalized_original_map NONE
# 2694
# normalized_original_map NONE
# 2695
# normalized_original_map NONE
# 2696
# normalized_original_map NONE
# 2697
# normalized_original_map NONE
# 2698
# normalized_original_map NONE
# 2699
# normalized_original_map NONE
# 2700
# normalized_original_map NONE
# 2701
# normalized_original_map NONE
# 2702
# normalized_original_map NONE
# 2703
# normalized_original_map NONE
# 2704
# normalized_original_map NONE
# 2705
# normalized_original_map NONE
# 2706
# normalized_original_map NONE
# 2707
# normalized_original_map NONE
# 2708
# normalized_original_map NONE
# 2709
# normalized_original_map NONE
# 2710
# normalized_original_map NONE
# 2711
# normalized_original_map NONE
# 2712
# normalized_original_map NONE
# 2713
# normalized_original_map NONE
# 2714
# normalized_original_map NONE
# 2715
# normalized_original_map NONE
# 2716
# normalized_original_map NONE
# 2717
# normalized_original_map NONE
# 2718
# normalized_original_map NONE
# 2719
# normalized_original_map NONE
# 2720
# normalized_original_map NONE
# 2721
# normalized_original_map NONE
# 2722
# normalized_original_map NONE
# 2723
# normalized_original_map NONE
# 2724
# normalized_original_map NONE
# 2725
# normalized_original_map NONE
# 2726
# normalized_original_map NONE
# 2727
# normalized_original_map NONE
# 2728
# normalized_original_map NONE
# 2729
# normalized_original_map NONE
# 2730
# normalized_original_map NONE
# 2731
# normalized_original_map NONE
# 2732
# normalized_original_map NONE
# 2733
# normalized_original_map NONE
# 2734
# normalized_original_map NONE
# 2735
# normalized_original_map NONE
# 2736
# normalized_original_map NONE
# 2737
# normalized_original_map NONE
# 2738
# normalized_original_map NONE
# 2739
# normalized_original_map NONE
# 2740
# normalized_original_map NONE
# 2741
# normalized_original_map NONE
# 2742
# normalized_original_map NONE
# 2743
# normalized_original_map NONE
# 2744
# normalized_original_map NONE
# 2745
# normalized_original_map NONE
# 2746
# normalized_original_map NONE
# 2747
# normalized_original_map NONE
# 2748
# normalized_original_map NONE
# 2749
# normalized_original_map NONE
# 2750
# normalized_original_map NONE
# 2751
# normalized_original_map NONE
# 2752
# normalized_original_map NONE
# 2753
# normalized_original_map NONE
# 2754
# normalized_original_map NONE
# 2755
# normalized_original_map NONE
# 2756
# normalized_original_map NONE
# 2757
# normalized_original_map NONE
# 2758
# normalized_original_map NONE
# 2759
# normalized_original_map NONE
# 2760
# normalized_original_map NONE
# 2761
# normalized_original_map NONE
# 2762
# normalized_original_map NONE
# 2763
# normalized_original_map NONE
# 2764
# normalized_original_map NONE
# 2765
# normalized_original_map NONE
# 2766
# normalized_original_map NONE
# 2767
# normalized_original_map NONE
# 2768
# normalized_original_map NONE
# 2769
# normalized_original_map NONE
# 2770
# normalized_original_map NONE
# 2771
# normalized_original_map NONE
# 2772
# normalized_original_map NONE
# 2773
# normalized_original_map NONE
# 2774
# normalized_original_map NONE
# 2775
# normalized_original_map NONE
# 2776
# normalized_original_map NONE
# 2777
# normalized_original_map NONE
# 2778
# normalized_original_map NONE
# 2779
# normalized_original_map NONE
# 2780
# normalized_original_map NONE
# 2781
# normalized_original_map NONE
# 2782
# normalized_original_map NONE
# 2783
# normalized_original_map NONE
# 2784
# normalized_original_map NONE
# 2785
# normalized_original_map NONE
# 2786
# normalized_original_map NONE
# 2787
# normalized_original_map NONE
# 2788
# normalized_original_map NONE
# 2789
# normalized_original_map NONE
# 2790
# normalized_original_map NONE
# 2791
# normalized_original_map NONE
# 2792
# normalized_original_map NONE
# 2793
# normalized_original_map NONE
# 2794
# normalized_original_map NONE
# 2795
# normalized_original_map NONE
# 2796
# normalized_original_map NONE
# 2797
# normalized_original_map NONE
# 2798
# normalized_original_map NONE
# 2799
# normalized_original_map NONE
# 2800
# normalized_original_map NONE
# 2801
# normalized_original_map NONE
# 2802
# normalized_original_map NONE
# 2803
# normalized_original_map NONE
# 2804
# normalized_original_map NONE
# 2805
# normalized_original_map NONE
# 2806
# normalized_original_map NONE
# 2807
# normalized_original_map NONE
# 2808
# normalized_original_map NONE
# 2809
# normalized_original_map NONE
# 2810
# normalized_original_map NONE
# 2811
# normalized_original_map NONE
# 2812
# normalized_original_map NONE
# 2813
# normalized_original_map NONE
# 2814
# normalized_original_map NONE
# 2815
# normalized_original_map NONE
# 2816
# normalized_original_map NONE
# 2817
# normalized_original_map NONE
# 2818
# normalized_original_map NONE
# 2819
# normalized_original_map NONE
# 2820
# normalized_original_map NONE
# 2821
# normalized_original_map NONE
# 2822
# normalized_original_map NONE
# 2823
# normalized_original_map NONE
# 2824
# normalized_original_map NONE
# 2825
# normalized_original_map NONE
# 2826
# normalized_original_map NONE
# 2827
# normalized_original_map NONE
# 2828
# normalized_original_map NONE
# 2829
# normalized_original_map NONE
# 2830
# normalized_original_map NONE
# 2831
# normalized_original_map NONE
# 2832
# normalized_original_map NONE
# 2833
# normalized_original_map NONE
# 2834
# normalized_original_map NONE
# 2835
# normalized_original_map NONE
# 2836
# normalized_original_map NONE
# 2837
# normalized_original_map NONE
# 2838
# normalized_original_map NONE
# 2839
# normalized_original_map NONE
# 2840
# normalized_original_map NONE
# 2841
# normalized_original_map NONE
# 2842
# normalized_original_map NONE
# 2843
# normalized_original_map NONE
# 2844
# normalized_original_map NONE
# 2845
# normalized_original_map NONE
# 2846
# normalized_original_map NONE
# 2847
# normalized_original_map NONE
# 2848
# normalized_original_map NONE
# 2849
# normalized_original_map NONE
# 2850
# normalized_original_map NONE
# 2851
# normalized_original_map NONE
# 2852
# normalized_original_map NONE
# 2853
# normalized_original_map NONE
# 2854
# normalized_original_map NONE
# 2855
# normalized_original_map NONE
# 2856
# normalized_original_map NONE
# 2857
# normalized_original_map NONE
# 2858
# normalized_original_map NONE
# 2859
# normalized_original_map NONE
# 2860
# normalized_original_map NONE
# 2861
# normalized_original_map NONE
# 2862
# normalized_original_map NONE
# 2863
# normalized_original_map NONE
# 2864
# normalized_original_map NONE
# 2865
# normalized_original_map NONE
# 2866
# normalized_original_map NONE
# 2867
# normalized_original_map NONE
# 2868
# normalized_original_map NONE
# 2869
# normalized_original_map NONE
# 2870
# normalized_original_map NONE
# 2871
# normalized_original_map NONE
# 2872
# normalized_original_map NONE
# 2873
# normalized_original_map NONE
# 2874
# normalized_original_map NONE
# 2875
# normalized_original_map NONE
# 2876
# normalized_original_map NONE
# 2877
# normalized_original_map NONE
# 2878
# normalized_original_map NONE
# 2879
# normalized_original_map NONE
# 2880
# normalized_original_map NONE
# 2881
# normalized_original_map NONE
# 2882
# normalized_original_map NONE
# 2883
# normalized_original_map NONE
# 2884
# normalized_original_map NONE
# 2885
# normalized_original_map NONE
# 2886
# normalized_original_map NONE
# 2887
# normalized_original_map NONE
# 2888
# normalized_original_map NONE
# 2889
# normalized_original_map NONE
# 2890
# normalized_original_map NONE
# 2891
# normalized_original_map NONE
# 2892
# normalized_original_map NONE
# 2893
# normalized_original_map NONE
# 2894
# normalized_original_map NONE
# 2895
# normalized_original_map NONE
# 2896
# normalized_original_map NONE
# 2897
# normalized_original_map NONE
# 2898
# normalized_original_map NONE
# 2899
# normalized_original_map NONE
# 2900
# normalized_original_map NONE
# 2901
# normalized_original_map NONE
# 2902
# normalized_original_map NONE
# 2903
# normalized_original_map NONE
# 2904
# normalized_original_map NONE
# 2905
# normalized_original_map NONE
# 2906
# normalized_original_map NONE
# 2907
# normalized_original_map NONE
# 2908
# normalized_original_map NONE
# 2909
# normalized_original_map NONE
# 2910
# normalized_original_map NONE
# 2911
# normalized_original_map NONE
# 2912
# normalized_original_map NONE
# 2913
# normalized_original_map NONE
# 2914
# normalized_original_map NONE
# 2915
# normalized_original_map NONE
# 2916
# normalized_original_map NONE
# 2917
# normalized_original_map NONE
# 2918
# normalized_original_map NONE
# 2919
# normalized_original_map NONE
# 2920
# normalized_original_map NONE
# 2921
# normalized_original_map NONE
# 2922
# normalized_original_map NONE
# 2923
# normalized_original_map NONE
# 2924
# normalized_original_map NONE
# 2925
# normalized_original_map NONE
# 2926
# normalized_original_map NONE
# 2927
# normalized_original_map NONE
# 2928
# normalized_original_map NONE
# 2929
# normalized_original_map NONE
# 2930
# normalized_original_map NONE
# 2931
# normalized_original_map NONE
# 2932
# normalized_original_map NONE
# 2933
# normalized_original_map NONE
# 2934
# normalized_original_map NONE
# 2935
# normalized_original_map NONE
# 2936
# normalized_original_map NONE
# 2937
# normalized_original_map NONE
# 2938
# normalized_original_map NONE
# 2939
# normalized_original_map NONE
# 2940
# normalized_original_map NONE
# 2941
# normalized_original_map NONE
# 2942
# normalized_original_map NONE
# 2943
# normalized_original_map NONE
# 2944
# normalized_original_map NONE
# 2945
# normalized_original_map NONE
# 2946
# normalized_original_map NONE
# 2947
# normalized_original_map NONE
# 2948
# normalized_original_map NONE
# 2949
# normalized_original_map NONE
# 2950
# normalized_original_map NONE
# 2951
# normalized_original_map NONE
# 2952
# normalized_original_map NONE
# 2953
# normalized_original_map NONE
# 2954
# normalized_original_map NONE
# 2955
# normalized_original_map NONE
# 2956
# normalized_original_map NONE
# 2957
# normalized_original_map NONE
# 2958
# normalized_original_map NONE
# 2959
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 49
#      19 if __name__ == '__main__':
#      20
#      21     #Aumentar o limiar para testar se fica compatível no máximo valor
#      22     #Gerar as curvas de bezier dentro do algoritmo - tamanho setado pelo cliente - distancia entre o ponto 1 e ponto 2, numero de pontos, max_vd,
#      23     parameters ={
#      24         'dir_maps_pickle': f'{root_dir}/Vessel_models_pickle/retina/10_maps',  # directory of pickles
#      25         'dir_mask': f'{root_dir}/Images/retina/mask',  # directory of pickles
#    (...)
#      47         'padding': 50,  # padding used to ensure that the trace does not exceed the size of the background
#      48     }
# ---> 49     backgen.generate_backgrounds_with_vessels_retina(parameters)
#
# File c:\Users\adria\Documents\Mestrado\texture_codes\modules\Background\background_generation.py:1267, in generate_backgrounds_with_vessels_retina(params)
#    1265 points, distance = create_points(number_points, padding, number_rows, number_cols, min_len_trace, max_len_trace)
#    1266 curve = create_curve(points, max_distance, control_points, precision)
# -> 1267 results = insert_vessels_retina(curve, distance, array_maps_pickle,dir_maps_pickle,background,threshold,path_pickle)
#    1268 if results is not None:
#    1269     vessel_without_artifacts, map_without_artifacts, mask_map, threshold = results
#
# File c:\Users\adria\Documents\Mestrado\texture_codes\modules\Background\background_generation.py:858, in insert_vessels_retina(medial_path_array, distance, pickles_array, pickle_dir, back_artifact, threshold, path_pickle)
#     855 binary_map_without_artifacts = fill_holes(binary_map_without_lateral_artifacts)
#     857 # Normalize the original map based on background artifact, binary map without artifacts, and a threshold
# --> 858 normalized_original_map = normalize_retina(back_artifact, original_map, binary_map_without_artifacts, threshold)
#     860 # Return None if normalized map is None
#     861 if normalized_original_map is None:
#
# File c:\Users\adria\Documents\Mestrado\texture_codes\modules\Background\background_generation.py:645, in normalize_retina(img_background, img_map, vessel_mask, threshold)
#     642 ints_map = img_map[vessel_mask == 0]
#     644 # Calculate mean and standard deviation for both background and map intensities
# --> 645 mean_background = np.mean(ints_background)
#     646 std_background = 1 #np.std(ints_background)
#     647 mean_map = np.mean(ints_map)
#
# File <__array_function__ internals>:200, in mean(*args, **kwargs)
#
# File c:\Users\adria\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3464, in mean(a, axis, dtype, out, keepdims, where)
#    3461     else:
#    3462         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3464 return _methods._mean(a, axis=axis, dtype=dtype,
#    3465                       out=out, **kwargs)
#
# File c:\Users\adria\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:181, in _mean(a, axis, dtype, out, keepdims, where)
#     178         dtype = mu.dtype('f4')
#     179         is_float16_result = True
# --> 181 ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     182 if isinstance(ret, mu.ndarray):
#     183     with _no_nep50_warning():
#
# KeyboardInterrupt:
